# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# %%
df=pd.read_csv('intel dataset.csv')

# %%
df
# Out:
#                             Date       Open       High        Low      Close  \
# 0      1980-03-17 00:00:00-05:00   0.181500   0.184404   0.181500   0.181500
# 1      1980-03-18 00:00:00-05:00   0.181500   0.182952   0.180048   0.180048
# 2      1980-03-19 00:00:00-05:00   0.184404   0.187308   0.184404   0.184404
# 3      1980-03-20 00:00:00-05:00   0.184403   0.186581   0.183678   0.183678
# 4      1980-03-21 00:00:00-05:00   0.180048   0.180048   0.177143   0.177143
# ...                          ...        ...        ...        ...        ...
# 11284  2024-12-18 00:00:00-05:00  20.480000  20.580000  19.209999  19.299999
# 11285  2024-12-19 00:00:00-05:00  19.530001  19.690001  19.030001  19.059999
# 11286  2024-12-20 00:00:00-05:00  18.969999  19.760000  18.900000  19.520000
# 11287  2024-12-23 00:00:00-05:00  19.580000  20.230000  19.520000  20.200001
# 11288  2024-12-24 00:00:00-05:00  20.219999  20.400000  19.959999  20.400000
#
#           Volume  Dividends  Stock Splits
# ...

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  11289.000000  11289.000000  11289.000000  11289.000000  1.128900e+04
# mean      14.986168     15.185892     14.787731     14.985933  5.064025e+07
# std       14.708247     14.892642     14.526521     14.709644  3.475946e+07
# min        0.121968      0.121968      0.120516      0.120516  0.000000e+00
# 25%        0.810214      0.827638      0.797147      0.814571  2.744880e+07
# 50%       12.757638     12.917269     12.590077     12.742243  4.456490e+07
# 75%       22.624974     22.879999     22.350709     22.617407  6.459720e+07
# max       62.028760     62.292520     60.600833     62.083344  5.677088e+08
#
#           Dividends  Stock Splits
# count  11289.000000  11289.000000
# mean       0.001581      0.001373
# std        0.019592      0.051749
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11289 entries, 0 to 11288
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          11289 non-null  object
#  1   Open          11289 non-null  float64
#  2   High          11289 non-null  float64
#  3   Low           11289 non-null  float64
#  4   Close         11289 non-null  float64
#  5   Volume        11289 non-null  int64
#  6   Dividends     11289 non-null  float64
#  7   Stock Splits  11289 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 705.7+ KB

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df["High"].mean()
# Out:
# 15.18589170801116

# %%
df['High'].hist()
# Out:
# <Axes: >

# %%
plt.scatter(df['High'],df['Low'])

# %%
plt.boxplot(df['High'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79e5076a68d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79e5076a7cd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79e509d0b710>],
#  'medians': [<matplotlib.lines.Line2D at 0x79e5076b1150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79e5076b19d0>],
#  'means': []}

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["Low"], y=df["High"], color="red")
# Out:
# <Axes: xlabel='Low', ylabel='High'>

# %%
# Select numeric columns (corrected line)
dataset_numeric = df.select_dtypes(include=['number'])  # No backslash or extra characters

# Compute the correlation matrix
cor_matrix = dataset_numeric.corr()

# Heatmap part
plt.figure(figsize=(10, 8))
sns.heatmap(cor_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f",
            linewidths=0.5,
            square=True,
            cbar_kws={'label': 'Correlation'})

# Customize the plot
plt.title("Correlation Matrix of Financial Data", fontsize=16, pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

# Display the heatmap
plt.show()
